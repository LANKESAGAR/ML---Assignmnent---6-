# %% [markdown]
# # Question - 2

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import preprocessing,metrics
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import silhouette_score

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('D:/Fall2022/ML Class/Assignment - 6/CC GENERAL.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.083333
# 50%                 89.000000      0.000000             0.500000
# 75%                468.637500   1113.821139             0.916667
# max              22500.000000  47137.211760             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 8950.000000                       8950.000000
# mean                     0.202458                          0.364437
# std                      0.298336                          0.397448
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.083333                          0.166667
# 75%                      0.300000                          0.750000
# max                      1.000000                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# count             8950.000000       8950.000000    8950.000000   8949.000000
# mean                 0.135144          3.248827      14.709832   4494.449450
# std                  0.200121          6.824647      24.857649   3638.815725
# min                  0.000000          0.000000       0.000000     50.000000
# 25%                  0.000000          0.000000       1.000000   1600.000000
# 50%                  0.000000          0.000000       7.000000   3000.000000
# 75%                  0.222222          4.000000      17.000000   6500.000000
# max                  1.500000        123.000000     358.000000  30000.000000
#
#            PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE
# count   8950.000000       8637.000000       8950.000000  8950.000000
# mean    1733.143852        864.206542          0.153715    11.517318
# std     2895.063757       2372.446607          0.292499     1.338331
# min        0.000000          0.019163          0.000000     6.000000
# 25%      383.276166        169.123707          0.000000    12.000000
# 50%      856.901546        312.343947          0.000000    12.000000
# 75%     1901.134317        825.485459          0.142857    12.000000
# max    50721.483360      76406.207520          1.000000    12.000000

# %% [markdown]
# # 2 - a Preprocessing the data by removing the categorical column and filling the missing values.

# %%
#Trying to find if there is any null value
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
# Null values are found in the CREDIT_LIMIT and MINIMUM_PAYMENTS
# Now filling those null values with the mean of that coloumn values
df['CREDIT_LIMIT'].fillna(df['CREDIT_LIMIT'].mean(), inplace=True)
df['MINIMUM_PAYMENTS'].fillna(df['MINIMUM_PAYMENTS'].mean(), inplace=True)

# %%
# Again checking if there is any null values
df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8950 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8950 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %%
# dropping the categorical values in the column of CUST_ID)
df.drop('CUST_ID', axis=1, inplace=True)
df.head(1)
# Out:
#      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  40.900749           0.818182       95.4               0.0
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4           0.0             0.166667
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                         0.0                          0.083333
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                     0.0                 0              2        1000.0
#
#      PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0  201.802084        139.509787               0.0      12

# %%
df.corr().style.background_gradient(cmap="Reds")
# Out:
# <style  type="text/css" >
# #T_b7ce7_row0_col0,#T_b7ce7_row1_col1,#T_b7ce7_row2_col2,#T_b7ce7_row3_col3,#T_b7ce7_row4_col4,#T_b7ce7_row5_col5,#T_b7ce7_row6_col6,#T_b7ce7_row7_col7,#T_b7ce7_row8_col8,#T_b7ce7_row9_col9,#T_b7ce7_row10_col10,#T_b7ce7_row11_col11,#T_b7ce7_row12_col12,#T_b7ce7_row13_col13,#T_b7ce7_row14_col14,#T_b7ce7_row15_col15,#T_b7ce7_row16_col16{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_b7ce7_row0_col1,#T_b7ce7_row1_col9,#T_b7ce7_row2_col0,#T_b7ce7_row4_col3,#T_b7ce7_row4_col15,#T_b7ce7_row12_col13,#T_b7ce7_row13_col10{
#             background-color:  #fc9070;
#             color:  #000000;
#         }#T_b7ce7_row0_col2,#T_b7ce7_row15_col2,#T_b7ce7_row16_col8{
#             background-color:  #fcb69b;
#             color:  #000000;
#         }#T_b7ce7_row0_col3,#T_b7ce7_row0_col4,#T_b7ce7_row1_col2,#T_b7ce7_row1_col4,#T_b7ce7_row8_col7,#T_b7ce7_row11_col12,#T_b7ce7_row16_col15{
#             background-color:  #fcc2aa;
#             color:  #000000;
#         }#T_b7ce7_row0_col5,#T_b7ce7_row8_col11,#T_b7ce7_row9_col0{
#             background-color:  #f34a36;
#             color:  #000000;
#         }#T_b7ce7_row0_col6,#T_b7ce7_row5_col1{
#             background-color:  #fdd1be;
#             color:  #000000;
#         }#T_b7ce7_row0_col7,#T_b7ce7_row3_col14{
#             background-color:  #fdd4c2;
#             color:  #000000;
#         }#T_b7ce7_row0_col8{
#             background-color:  #fdd7c6;
#             color:  #000000;
#         }#T_b7ce7_row0_col9,#T_b7ce7_row11_col3{
#             background-color:  #f34c37;
#             color:  #000000;
#         }#T_b7ce7_row0_col10{
#             background-color:  #fb6d4d;
#             color:  #000000;
#         }#T_b7ce7_row0_col11,#T_b7ce7_row7_col12{
#             background-color:  #fcbba1;
#             color:  #000000;
#         }#T_b7ce7_row0_col12{
#             background-color:  #fb694a;
#             color:  #000000;
#         }#T_b7ce7_row0_col13,#T_b7ce7_row13_col8{
#             background-color:  #fcb398;
#             color:  #000000;
#         }#T_b7ce7_row0_col14{
#             background-color:  #fb7555;
#             color:  #000000;
#         }#T_b7ce7_row0_col15,#T_b7ce7_row1_col13,#T_b7ce7_row6_col5,#T_b7ce7_row6_col9,#T_b7ce7_row6_col10,#T_b7ce7_row9_col2,#T_b7ce7_row9_col3,#T_b7ce7_row9_col4,#T_b7ce7_row9_col6,#T_b7ce7_row9_col7,#T_b7ce7_row9_col8,#T_b7ce7_row9_col11,#T_b7ce7_row9_col16,#T_b7ce7_row15_col0,#T_b7ce7_row15_col1,#T_b7ce7_row15_col12,#T_b7ce7_row15_col14{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_b7ce7_row0_col16,#T_b7ce7_row3_col1,#T_b7ce7_row6_col0,#T_b7ce7_row8_col16{
#             background-color:  #fdd0bc;
#             color:  #000000;
#         }#T_b7ce7_row1_col0,#T_b7ce7_row13_col0{
#             background-color:  #fb6e4e;
#             color:  #000000;
#         }#T_b7ce7_row1_col3,#T_b7ce7_row3_col9,#T_b7ce7_row3_col16,#T_b7ce7_row6_col16,#T_b7ce7_row12_col1,#T_b7ce7_row16_col7,#T_b7ce7_row16_col14{
#             background-color:  #fdd2bf;
#             color:  #000000;
#         }#T_b7ce7_row1_col5,#T_b7ce7_row11_col1,#T_b7ce7_row14_col10,#T_b7ce7_row15_col11{
#             background-color:  #fcb89e;
#             color:  #000000;
#         }#T_b7ce7_row1_col6{
#             background-color:  #fc8666;
#             color:  #000000;
#         }#T_b7ce7_row1_col7,#T_b7ce7_row1_col11,#T_b7ce7_row12_col15,#T_b7ce7_row16_col6{
#             background-color:  #fcb095;
#             color:  #000000;
#         }#T_b7ce7_row1_col8{
#             background-color:  #fc9c7d;
#             color:  #000000;
#         }#T_b7ce7_row1_col10{
#             background-color:  #fcaf93;
#             color:  #000000;
#         }#T_b7ce7_row1_col12,#T_b7ce7_row6_col13{
#             background-color:  #ffeee7;
#             color:  #000000;
#         }#T_b7ce7_row1_col14,#T_b7ce7_row1_col16,#T_b7ce7_row11_col16,#T_b7ce7_row16_col11{
#             background-color:  #fcc3ab;
#             color:  #000000;
#         }#T_b7ce7_row1_col15,#T_b7ce7_row14_col16{
#             background-color:  #fdd3c1;
#             color:  #000000;
#         }#T_b7ce7_row2_col1,#T_b7ce7_row9_col14{
#             background-color:  #fdc7b2;
#             color:  #000000;
#         }#T_b7ce7_row2_col3,#T_b7ce7_row3_col2{
#             background-color:  #8c0912;
#             color:  #f1f1f1;
#         }#T_b7ce7_row2_col4,#T_b7ce7_row5_col9,#T_b7ce7_row10_col5{
#             background-color:  #d42121;
#             color:  #f1f1f1;
#         }#T_b7ce7_row2_col5,#T_b7ce7_row4_col9,#T_b7ce7_row11_col9,#T_b7ce7_row14_col15,#T_b7ce7_row16_col3,#T_b7ce7_row16_col9,#T_b7ce7_row16_col10{
#             background-color:  #fedecf;
#             color:  #000000;
#         }#T_b7ce7_row2_col6,#T_b7ce7_row3_col13{
#             background-color:  #f75c41;
#             color:  #000000;
#         }#T_b7ce7_row2_col7,#T_b7ce7_row13_col5{
#             background-color:  #f6583e;
#             color:  #000000;
#         }#T_b7ce7_row2_col8,#T_b7ce7_row6_col2{
#             background-color:  #fb7757;
#             color:  #000000;
#         }#T_b7ce7_row2_col9{
#             background-color:  #fedbcc;
#             color:  #000000;
#         }#T_b7ce7_row2_col10,#T_b7ce7_row7_col10,#T_b7ce7_row10_col15{
#             background-color:  #fee3d6;
#             color:  #000000;
#         }#T_b7ce7_row2_col11,#T_b7ce7_row11_col2{
#             background-color:  #d21f20;
#             color:  #f1f1f1;
#         }#T_b7ce7_row2_col12,#T_b7ce7_row13_col7{
#             background-color:  #fca588;
#             color:  #000000;
#         }#T_b7ce7_row2_col13{
#             background-color:  #f44d38;
#             color:  #000000;
#         }#T_b7ce7_row2_col14,#T_b7ce7_row10_col13,#T_b7ce7_row11_col14{
#             background-color:  #fdc9b3;
#             color:  #000000;
#         }#T_b7ce7_row2_col15,#T_b7ce7_row13_col9{
#             background-color:  #fc9272;
#             color:  #000000;
#         }#T_b7ce7_row2_col16,#T_b7ce7_row4_col16,#T_b7ce7_row8_col0,#T_b7ce7_row8_col3,#T_b7ce7_row16_col4{
#             background-color:  #fdccb8;
#             color:  #000000;
#         }#T_b7ce7_row3_col0,#T_b7ce7_row11_col15,#T_b7ce7_row12_col7{
#             background-color:  #fc9576;
#             color:  #000000;
#         }#T_b7ce7_row3_col4{
#             background-color:  #fc8767;
#             color:  #000000;
#         }#T_b7ce7_row3_col5,#T_b7ce7_row7_col9,#T_b7ce7_row8_col14{
#             background-color:  #fed9c9;
#             color:  #000000;
#         }#T_b7ce7_row3_col6{
#             background-color:  #fb7d5d;
#             color:  #000000;
#         }#T_b7ce7_row3_col7,#T_b7ce7_row4_col6{
#             background-color:  #f44f39;
#             color:  #000000;
#         }#T_b7ce7_row3_col8,#T_b7ce7_row14_col9{
#             background-color:  #fca78b;
#             color:  #000000;
#         }#T_b7ce7_row3_col10{
#             background-color:  #fedfd0;
#             color:  #000000;
#         }#T_b7ce7_row3_col11,#T_b7ce7_row13_col3{
#             background-color:  #f14432;
#             color:  #f1f1f1;
#         }#T_b7ce7_row3_col12,#T_b7ce7_row15_col4{
#             background-color:  #fcb296;
#             color:  #000000;
#         }#T_b7ce7_row3_col15,#T_b7ce7_row4_col13,#T_b7ce7_row12_col4{
#             background-color:  #fc9d7f;
#             color:  #000000;
#         }#T_b7ce7_row4_col0,#T_b7ce7_row12_col9{
#             background-color:  #fc9e80;
#             color:  #000000;
#         }#T_b7ce7_row4_col1,#T_b7ce7_row14_col11{
#             background-color:  #fdcab5;
#             color:  #000000;
#         }#T_b7ce7_row4_col2,#T_b7ce7_row5_col10{
#             background-color:  #d52221;
#             color:  #f1f1f1;
#         }#T_b7ce7_row4_col5,#T_b7ce7_row14_col3,#T_b7ce7_row16_col5{
#             background-color:  #fee1d3;
#             color:  #000000;
#         }#T_b7ce7_row4_col7,#T_b7ce7_row6_col1,#T_b7ce7_row12_col10{
#             background-color:  #fcad90;
#             color:  #000000;
#         }#T_b7ce7_row4_col8{
#             background-color:  #f0402f;
#             color:  #f1f1f1;
#         }#T_b7ce7_row4_col10,#T_b7ce7_row7_col5{
#             background-color:  #fee3

# %% [markdown]
# # 2 - b Applying the StandardScaler() and normalize() functions to scale and normalize raw input data.

# %%
x = df.iloc[:,0:-1]
y = df.iloc[:,-1]


scaler = preprocessing.StandardScaler()
scaler.fit(x)
X_scaled_array = scaler.transform(x)
X_scaled_df = pd.DataFrame(X_scaled_array, columns = x.columns)

# %%
X_normalized = preprocessing.normalize(X_scaled_df)
X_normalized = pd.DataFrame(X_normalized)

# %% [markdown]
# # 2 - c Using PCA with K=2 to reduce the input dimensions to two features.

# %%
pca2 = PCA(n_components=2)
principalComponents = pca2.fit_transform(X_normalized)

principalDf = pd.DataFrame(data = principalComponents, columns = ['P1', 'P2'])

finalDf = pd.concat([principalDf, df[['TENURE']]], axis = 1)
finalDf.head()
# Out:
#          P1        P2  TENURE
# 0 -0.488186 -0.677233      12
# 1 -0.517294  0.556073      12
# 2  0.334384  0.287314      12
# 3 -0.486616 -0.080780      12
# 4 -0.562175 -0.474770      12

# %% [markdown]
# # 2 - d Applying Agglomerative Clustering with k=2,3,4 and 5 on reduced features and visualising the result for each k value using scatter plot.

# %%
plt.figure(figsize=(7,7))
plt.scatter(finalDf['P1'],finalDf['P2'],c=finalDf['TENURE'],cmap='prism', s =5)
plt.xlabel('pc1')
plt.ylabel('pc2')
# Out:
# Text(0, 0.5, 'pc2')

# %%
ac2 = AgglomerativeClustering(n_clusters = 2)
 
# Visualizing the clustering
plt.figure(figsize =(6, 6))
plt.scatter(principalDf['P1'], principalDf['P2'],
           c = ac2.fit_predict(principalDf), cmap ='rainbow')
plt.show()

# %%
ac3 = AgglomerativeClustering(n_clusters = 3)
 
# Visualizing the clustering
plt.figure(figsize =(6, 6))
plt.scatter(principalDf['P1'], principalDf['P2'],
           c = ac3.fit_predict(principalDf), cmap ='rainbow')
plt.show()

# %%
ac4 = AgglomerativeClustering(n_clusters = 4)
 
# Visualizing the clustering
plt.figure(figsize =(6, 6))
plt.scatter(principalDf['P1'], principalDf['P2'],
           c = ac4.fit_predict(principalDf), cmap ='rainbow')
plt.show()

# %%
ac5 = AgglomerativeClustering(n_clusters = 5)
 
# Visualizing the clustering
plt.figure(figsize =(6, 6))
plt.scatter(principalDf['P1'], principalDf['P2'],
           c = ac5.fit_predict(principalDf), cmap ='rainbow')
plt.show()

# %% [markdown]
# # 2 - e Evaluating the different variations using Silhouette Scores and Visualising results with a bar chart

# %%
k = [2, 3, 4, 5]
 
# Appending the silhouette scores of the different models to the list
silhouette_scores = []
silhouette_scores.append(
        silhouette_score(principalDf, ac2.fit_predict(principalDf)))
silhouette_scores.append(
        silhouette_score(principalDf, ac3.fit_predict(principalDf)))
silhouette_scores.append(
        silhouette_score(principalDf, ac4.fit_predict(principalDf)))
silhouette_scores.append(
        silhouette_score(principalDf, ac5.fit_predict(principalDf)))

 
# Plotting a bar graph to compare the results
plt.bar(k, silhouette_scores)
plt.xlabel('Number of clusters', fontsize = 20)
plt.ylabel('S(i)', fontsize = 20)
plt.show()
